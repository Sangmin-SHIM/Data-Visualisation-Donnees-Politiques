# %%
import pandas as pd
import datetime

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('geo_bureaux_de_vote_md.xlsx')

# %%
excel_votes_bureaux_de_vote = pd.ExcelFile('Les tendances de votes par bureau de vote pour les législatives (1er tour de 2017).xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
df_votes = pd.read_excel(excel_votes_bureaux_de_vote)

# %%
df_geo.rename(columns={'code':'Code du b.vote'}, inplace=True)
df_geo
# Out:
#       commune_code                  libelle Code du b.vote  \
# 0             1001  L'Abergement-Clémenciat              1
# 1             1002    L'Abergement-de-Varey              1
# 2             1004        Ambérieu-en-Bugey              1
# 3             1004        Ambérieu-en-Bugey              2
# 4             1004        Ambérieu-en-Bugey              3
# ...            ...                      ...            ...
# 60569        2B352          Ville-di-Paraso              1
# 60570        2B353     Ville-di-Pietrabugno              1
# 60571        2B353     Ville-di-Pietrabugno              2
# 60572        2B354                  Vivario              1
# 60573        2B355                Volpajola              2
#
#                        libelle.1 code_postal                commune longitude  \
# 0                       Bureau 1        1400  ABERGEMENT CLEMENCIAT  4.920902
# 1                         Mairie        1640  L'ABERGEMENT DE VAREY  5.423436
# 2               B1 - ESPACE 1500        1500      AMBERIEU-EN-BUGEY  5.348146
# 3               B2 - ESPACE 1500        1500      AMBERIEU-EN-BUGEY  5.348146
# 4      B3 - Château des Echelles        1500      AMBERIEU-EN-BUGEY  5.364613
# ...                          ...         ...                    ...       ...
# 60569        Bureau de Vote N° 1       20279        VILLE DI PARASO  8.993626
# 60570                     MAIRIE       20200   VILLE-DI-PIETRABUGNO  9.434536
# 60571              MAISON DU CAP       20200   VILLE-DI-PIETRABUGNO  9.454526
# 60572           Salle de réunion       20219                VIVARIO  9.152516
# 60573         Ecole de Barchetta       20290              VOLPAJOLA  9.351963
#
#         latitude
# 0      46.150784
# 1      46.007249
# 2      45.960048
# 3      45.960048
# 4      45.955227
# ...          ...
# 60569  42.581761
# 60570  42.711799
# 60571  42.709394
# 60572  42.152309
# 60573  42.510571
#
# [60574 rows x 8 columns]

# %%
df_votes.rename(columns={'Code du département':'commune_code'}, inplace=True)
df_votes
# Out:
#         commune_code Libellé du département  Code de la circonscription  \
# 0               1001                    Ain                         4.0
# 1               1002                    Ain                         5.0
# 2               1004                    Ain                         5.0
# 3               1004                    Ain                         5.0
# 4               1004                    Ain                         5.0
# ...              ...                    ...                         ...
# 1048570            0                    NaN                         NaN
# 1048571            0                    NaN                         NaN
# 1048572            0                    NaN                         NaN
# 1048573            0                    NaN                         NaN
# 1048574            0                    NaN                         NaN
#
#         Libellé de la circonscription  Code de la commune  \
# 0                4ème circonscription                 1.0
# 1                5ème circonscription                 2.0
# 2                5ème circonscription                 4.0
# 3                5ème circonscription                 4.0
# 4                5ème circonscription                 4.0
# ...                               ...                 ...
# 1048570                           NaN                 NaN
# 1048571                           NaN                 NaN
# 1048572                           NaN                 NaN
# 1048573                           NaN                 NaN
# 1048574                           NaN                 NaN
#
#            Libellé de la commune Code du b.vote  Inscrits  Abstentions  \
# 0        L'Abergement-Clémenciat              1     598.0        261.0
# 1          L'Abergement-de-Varey              1     211.0         79.0
# 2              Ambérieu-en-Bugey              1    1126.0        637.0
# 3              Ambérieu-en-Bugey              2    1134.0        579.0
# 4              Ambérieu-en-Bugey              3    1117.0        560.0
# ...                          ...            ...       ...          ...
# 1048570                      NaN            NaN       NaN          NaN
# 1048571                      NaN            NaN       NaN          NaN
# 1048572                      NaN            NaN       NaN          NaN
# 1048573                      NaN            NaN       NaN          NaN
# 1048574                      NaN            NaN       NaN          NaN
#
#         % Abs/Ins  ...  Unnamed: 227 Unnamed: 228  Unnamed: 229 Unnamed: 230  \
# 0           43,65  ...           NaN          NaN           NaN          NaN
# 1           37,44  ...           NaN          NaN           NaN          NaN
# 2           56,57  ...           NaN          NaN           NaN          NaN
# 3           51,06  ...           NaN          NaN           NaN          NaN
# 4           50,13  ...           NaN          NaN           NaN          NaN
# ...           ...  ...           ...          ...           ...          ...
# 1048570       NaN  ...           NaN          NaN           NaN          NaN
# 1048571       NaN  ...           NaN          NaN           NaN          NaN
# 1048572       NaN  ...           NaN          NaN           NaN          NaN
# 1048573       NaN  ...           NaN          NaN           NaN          NaN
# 1048574       NaN  ...           NaN          NaN           NaN          NaN
#
#         Unnamed: 231  Unnamed: 232 Unnamed: 233 Unnamed: 234  Unnamed: 235  \
# 0                NaN           NaN          NaN          NaN           NaN
# 1                NaN           NaN          NaN          NaN           NaN
# 2                NaN           NaN          NaN          NaN           NaN
# 3                NaN           NaN          NaN          NaN           NaN
# 4                NaN           NaN          NaN          NaN           NaN
# ...              ...           ...          ...          ...           ...
# 1048570          NaN           NaN          NaN          NaN           NaN
# 1048571          NaN           NaN          NaN          NaN           NaN
# 1048572          NaN           NaN          NaN          NaN           NaN
# 1048573          NaN           NaN          NaN          NaN           NaN
# 1048574          NaN           NaN          NaN          NaN           NaN
#
#         Unnamed: 236
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1048570          NaN
# 1048571          NaN
# 1048572          NaN
# 1048573          NaN
# 1048574          NaN
#
# [1048575 rows x 237 columns]

# %%
# Inner Join
df_INNER_JOIN = pd.merge(df_geo, df_votes, on=['commune_code','Code du b.vote'])

# %%
df_INNER_JOIN
# Out:
#       commune_code                  libelle Code du b.vote  \
# 0             1001  L'Abergement-Clémenciat              1
# 1             1002    L'Abergement-de-Varey              1
# 2             1004        Ambérieu-en-Bugey              1
# 3             1004        Ambérieu-en-Bugey              2
# 4             1004        Ambérieu-en-Bugey              3
# ...            ...                      ...            ...
# 55011        95680          Villiers-le-Bel             11
# 55012        95680          Villiers-le-Bel             12
# 55013        95680          Villiers-le-Bel             13
# 55014        95682          Villiers-le-Sec              1
# 55015        95690      Wy-dit-Joli-Village              1
#
#                                                libelle.1 code_postal  \
# 0                                               Bureau 1        1400
# 1                                                 Mairie        1640
# 2                                       B1 - ESPACE 1500        1500
# 3                                       B2 - ESPACE 1500        1500
# 4                              B3 - Château des Echelles        1500
# ...                                                  ...         ...
# 55011                     LE VILLAGE - ECOLE MARIE CURIE       95400
# 55012         LES CARREAUX - GROUPE SCOLAIRE JEAN JAURES       95400
# 55013  DERRIERE LES MURS - ECOLE MATERNELLE FERDINAND...       95400
# 55014                                             MAIRIE       95720
# 55015                                           Bureau 1       95420
#
#                      commune longitude   latitude Libellé du département  \
# 0      ABERGEMENT CLEMENCIAT  4.920902  46.150784                    Ain
# 1      L'ABERGEMENT DE VAREY  5.423436  46.007249                    Ain
# 2          AMBERIEU-EN-BUGEY  5.348146  45.960048                    Ain
# 3          AMBERIEU-EN-BUGEY  5.348146  45.960048                    Ain
# 4          AMBERIEU-EN-BUGEY  5.364613  45.955227                    Ain
# ...                      ...       ...        ...                    ...
# 55011        VILLIERS-LE-BEL  2.387895  49.006733             Val-d'Oise
# 55012        VILLIERS-LE-BEL  2.415228  49.001856             Val-d'Oise
# 55013        VILLIERS-LE-BEL  2.395384  49.003751             Val-d'Oise
# 55014        VILLIERS-LE-SEC  2.390021  49.072537             Val-d'Oise
# 55015    WY-DIT-JOLI-VILLAGE  1.835615  49.102958             Val-d'Oise
#
#        Code de la circonscription  ... Unnamed: 227  Unnamed: 228  \
# 0                             4.0  ...          NaN           NaN
# 1                             5.0  ...          NaN           NaN
# 2                             5.0  ...          NaN           NaN
# 3                             5.0  ...          NaN           NaN
# 4                             5.0  ...          NaN           NaN
# ...                           ...  ...          ...           ...
# 55011                         8.0  ...          NaN           NaN
# 55012                         8.0  ...          NaN           NaN
# 55013                         8.0  ...          NaN           NaN
# 55014                         9.0  ...          NaN           NaN
# 55015                         1.0  ...          NaN           NaN
#
#       Unnamed: 229  Unnamed: 230  Unnamed: 231 Unnamed: 232  Unnamed: 233  \
# 0              NaN           NaN           NaN          NaN           NaN
# 1              NaN           NaN           NaN          NaN           NaN
# 2              NaN           NaN           NaN          NaN           NaN
# 3              NaN           NaN           NaN          NaN           NaN
# 4              NaN           NaN           NaN          NaN           NaN
# ...            ...           ...           ...          ...           ...
# 55011          NaN           NaN           NaN          NaN           NaN
# 55012          NaN           NaN           NaN          NaN           NaN
# 55013          NaN           NaN           NaN          NaN           NaN
# 55014          NaN           NaN           NaN          NaN           NaN
# 55015          NaN           NaN           NaN          NaN           NaN
#
#       Unnamed: 234  Unnamed: 235 Unnamed: 236
# 0              NaN           NaN          NaN
# 1              NaN           NaN          NaN
# 2              NaN           NaN          NaN
# 3              NaN           NaN          NaN
# 4              NaN           NaN          NaN
# ...            ...           ...          ...
# 55011          NaN           NaN          NaN
# 55012          NaN           NaN          NaN
# 55013          NaN           NaN          NaN
# 55014          NaN           NaN          NaN
# 55015          NaN           NaN          NaN
#
# [55016 rows x 243 columns]

# %%
df_INNER_JOIN.to_excel('Les tendances de votes avec cordonnées pour les législatives (1er tour de 2017).xlsx')

# %%
excel_final=pd.ExcelFile('Les tendances de votes avec cordonnées pour les législatives (1er tour de 2017).xlsx')

# %%
df_commune = pd.read_excel(excel_final)

# %%
df_commune
# Out:
#        Unnamed: 0  commune_code                  libelle Code du b.vote  \
# 0               0          1001  L'Abergement-Clémenciat              1
# 1               1          1002    L'Abergement-de-Varey              1
# 2               2          1004        Ambérieu-en-Bugey              1
# 3               3          1004        Ambérieu-en-Bugey              2
# 4               4          1004        Ambérieu-en-Bugey              3
# ...           ...           ...                      ...            ...
# 55011       55011         95680          Villiers-le-Bel             11
# 55012       55012         95680          Villiers-le-Bel             12
# 55013       55013         95680          Villiers-le-Bel             13
# 55014       55014         95682          Villiers-le-Sec              1
# 55015       55015         95690      Wy-dit-Joli-Village              1
#
#                                                libelle.1 code_postal  \
# 0                                               Bureau 1        1400
# 1                                                 Mairie        1640
# 2                                       B1 - ESPACE 1500        1500
# 3                                       B2 - ESPACE 1500        1500
# 4                              B3 - Château des Echelles        1500
# ...                                                  ...         ...
# 55011                     LE VILLAGE - ECOLE MARIE CURIE       95400
# 55012         LES CARREAUX - GROUPE SCOLAIRE JEAN JAURES       95400
# 55013  DERRIERE LES MURS - ECOLE MATERNELLE FERDINAND...       95400
# 55014                                             MAIRIE       95720
# 55015                                           Bureau 1       95420
#
#                      commune longitude   latitude Libellé du département  ...  \
# 0      ABERGEMENT CLEMENCIAT  4.920902  46.150784                    Ain  ...
# 1      L'ABERGEMENT DE VAREY  5.423436  46.007249                    Ain  ...
# 2          AMBERIEU-EN-BUGEY  5.348146  45.960048                    Ain  ...
# 3          AMBERIEU-EN-BUGEY  5.348146  45.960048                    Ain  ...
# 4          AMBERIEU-EN-BUGEY  5.364613  45.955227                    Ain  ...
# ...                      ...       ...        ...                    ...  ...
# 55011        VILLIERS-LE-BEL  2.387895  49.006733             Val-d'Oise  ...
# 55012        VILLIERS-LE-BEL  2.415228  49.001856             Val-d'Oise  ...
# 55013        VILLIERS-LE-BEL  2.395384  49.003751             Val-d'Oise  ...
# 55014        VILLIERS-LE-SEC  2.390021  49.072537             Val-d'Oise  ...
# 55015    WY-DIT-JOLI-VILLAGE  1.835615  49.102958             Val-d'Oise  ...
#
#        Unnamed: 227 Unnamed: 228  Unnamed: 229 Unnamed: 230  Unnamed: 231  \
# 0               NaN          NaN           NaN          NaN           NaN
# 1               NaN          NaN           NaN          NaN           NaN
# 2               NaN          NaN           NaN          NaN           NaN
# 3               NaN          NaN           NaN          NaN           NaN
# 4               NaN          NaN           NaN          NaN           NaN
# ...             ...          ...           ...          ...           ...
# 55011           NaN          NaN           NaN          NaN           NaN
# 55012           NaN          NaN           NaN          NaN           NaN
# 55013           NaN          NaN           NaN          NaN           NaN
# 55014           NaN          NaN           NaN          NaN           NaN
# 55015           NaN          NaN           NaN          NaN           NaN
#
#        Unnamed: 232 Unnamed: 233  Unnamed: 234 Unnamed: 235  Unnamed: 236
# 0               NaN          NaN           NaN          NaN           NaN
# 1               NaN          NaN           NaN          NaN           NaN
# 2               NaN          NaN           NaN          NaN           NaN
# 3               NaN          NaN           NaN          NaN           NaN
# 4               NaN          NaN           NaN          NaN           NaN
# ...             ...          ...           ...          ...           ...
# 55011           NaN          NaN           NaN          NaN           NaN
# 55012           NaN          NaN           NaN          NaN           NaN
# 55013           NaN          NaN           NaN          NaN           NaN
# 55014           NaN          NaN           NaN          NaN           NaN
# 55015           NaN          NaN           NaN          NaN           NaN
#
# [55016 rows x 244 columns]

# %%
# Data Check for [longitude, latitude]
# ------------------------------------

# df_commune[df_commune.latitude.apply(type) == datetime.datetime]
# df_commune[df_commune.longitude.apply(type) == datetime.datetime]

# df_commune[df_commune.latitude.apply(type) == str]
# df_commune[df_commune.longitude.apply(type) == str]

# # Le Plus Voté - Nom, Prénom et % Voix / Ins
# # ------------------------------------------

# df_voix_exp = df_commune[['% Voix/Exp', '% Voix/Exp.1', '% Voix/Exp.2' , '% Voix/Exp.3' , '% Voix/Exp.4' , '% Voix/Exp.5' , '% Voix/Exp.6' , '% Voix/Exp.7', '% Voix/Exp.8', '% Voix/Exp.9', '% Voix/Exp.10']]

# class Candidat:
#     def __init__(self, nom, prenom):
#         self.nom = nom
#         self.prenom = prenom

# candidat=[]

# candidat.append(Candidat('DUPONT-AIGNAN','Nicolas'))
# for i in range(2,12):
#     candidat.append(Candidat(df_commune["Nom."+str(i-1)][0], df_commune["Prénom."+str(i-1)][0]))

# df_commune['NOM_candidat_le_plus_voté']=df_voix_exp.idxmax(axis=1).str.replace('% Voix/Exp','Nom')
# df_commune['PRENOM_candidat_le_plus_voté']=df_voix_exp.idxmax(axis=1).str.replace('% Voix/Exp','Prénom')

# df_commune['% Voix/Exp_le_plus_voté']=df_voix_exp.max(axis=1)

# df_commune.loc[(df_commune.NOM_candidat_le_plus_voté =='Nom'),'NOM_candidat_le_plus_voté'] = candidat[0].nom
# df_commune.loc[(df_commune.PRENOM_candidat_le_plus_voté =='Prénom'),'PRENOM_candidat_le_plus_voté'] = candidat[0].prenom
# for i in range(2,12):
#     df_commune.loc[(df_commune.NOM_candidat_le_plus_voté =='Nom.'+str(i-1),'NOM_candidat_le_plus_voté')] = candidat[i-1].nom
#     df_commune.loc[(df_commune.PRENOM_candidat_le_plus_voté =='Prénom.'+str(i-1),'PRENOM_candidat_le_plus_voté')] = candidat[i-1].prenom


# df.loc[(df.Event == 'Dance'),'Event']='Hip-Hop'
# df_commune.to_excel('Les tendances de votes avec cordonnées pour les législatives (1er tour de 2017).xlsx')

# %%
df_commune['Unnamed: 222'].notnull().sum()
# Out:
# 0
