# %%
import pandas as pd

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('EXCEL/geo_bureaux_de_vote_md.xlsx')

# %%
excel_votes_bureaux_de_vote = pd.ExcelFile('EXCEL/Les tendances de votes par bureau de vote pour les législatives (2eme tour de 2012).xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
df_votes = pd.read_excel(excel_votes_bureaux_de_vote)

# %%
df_geo.rename(columns={'code':'N° de bureau de vote'}, inplace=True)
df_geo
# Out:
#        Unnamed: 0 commune_code                  libelle N° de bureau de vote  \
# 0               0         1001  L'Abergement-Clémenciat                    1
# 1               1         1002    L'Abergement-de-Varey                    1
# 2               2         1004        Ambérieu-en-Bugey                    1
# 3               3         1004        Ambérieu-en-Bugey                    2
# 4               4         1004        Ambérieu-en-Bugey                    3
# ...           ...          ...                      ...                  ...
# 60566       60569        2B352          Ville-di-Paraso                    1
# 60567       60570        2B353     Ville-di-Pietrabugno                    1
# 60568       60571        2B353     Ville-di-Pietrabugno                    2
# 60569       60572        2B354                  Vivario                    1
# 60570       60573        2B355                Volpajola                    2
#
#                        libelle.1 code_postal                commune  \
# 0                       Bureau 1        1400  ABERGEMENT CLEMENCIAT
# 1                         Mairie        1640  L'ABERGEMENT DE VAREY
# 2               B1 - ESPACE 1500        1500      AMBERIEU-EN-BUGEY
# 3               B2 - ESPACE 1500        1500      AMBERIEU-EN-BUGEY
# 4      B3 - Château des Echelles        1500      AMBERIEU-EN-BUGEY
# ...                          ...         ...                    ...
# 60566        Bureau de Vote N° 1       20279        VILLE DI PARASO
# 60567                     MAIRIE       20200   VILLE-DI-PIETRABUGNO
# 60568              MAISON DU CAP       20200   VILLE-DI-PIETRABUGNO
# 60569           Salle de réunion       20219                VIVARIO
# 60570         Ecole de Barchetta       20290              VOLPAJOLA
#
#        longitude   latitude
# 0       4.920902  46.150784
# 1       5.423436  46.007249
# 2       5.348146  45.960048
# 3       5.348146  45.960048
# 4       5.364613  45.955227
# ...          ...        ...
# 60566   8.993626  42.581761
# 60567   9.434536  42.711799
# 60568   9.454526  42.709394
# 60569   9.152516  42.152309
# 60570   9.351963  42.510571
#
# [60571 rows x 9 columns]

# %%
df_votes.rename(columns={'Insee Code':'commune_code'}, inplace=True)
df_votes
# Out:
#        commune_code  N° de bureau de vote  Code de la commune  \
# 0              1001                   1.0                   1
# 1              1001                   1.0                   1
# 2              1002                   1.0                   2
# 3              1002                   1.0                   2
# 4              1004                   1.0                   4
# ...             ...                   ...                 ...
# 124388        95680                  13.0                 680
# 124389        95682                   1.0                 682
# 124390        95682                   1.0                 682
# 124391        95690                   1.0                 690
# 124392        95690                   1.0                 690
#
#               Nom de la commune  N° de circonscription  N° de canton  \
# 0       L'Abergement-Clémenciat                      4            10
# 1       L'Abergement-Clémenciat                      4            10
# 2         L'Abergement-de-Varey                      5             1
# 3         L'Abergement-de-Varey                      5             1
# 4             Ambérieu-en-Bugey                      5             1
# ...                         ...                    ...           ...
# 124388          Villiers-le-Bel                      8            35
# 124389          Villiers-le-Sec                      9            15
# 124390          Villiers-le-Sec                      9            15
# 124391      Wy-dit-Joli-Village                      1            16
# 124392      Wy-dit-Joli-Village                      1            16
#
#         Inscrits  Votants  Exprimés  N° de dépôt du candidat Nom du candidat  \
# 0            595      330       317                        8         LACROIX
# 1            595      330       317                        9          VOISIN
# 2            216      130       122                       41        EXPOSITO
# 3            216      130       122                       48            ABAD
# 4           1029      536       521                       41        EXPOSITO
# ...          ...      ...       ...                      ...             ...
# 124388       658      240       229                       97        BLANCHET
# 124389        95       71        71                       32           BLAZY
# 124390        95       71        71                       56      PATERNOTTE
# 124391       277      181       178                        8        HOUILLON
# 124392       277      181       178                       57        GRUNDLER
#
#        Prénom du candidat Code nuance du candidat  \
# 0               Guillaume                     RDG
# 1                  Michel                     UMP
# 2                 Josiane                     SOC
# 3                  Damien                     UMP
# 4                 Josiane                     SOC
# ...                   ...                     ...
# 124388       Marie-France                     UMP
# 124389        Jean-Pierre                     SOC
# 124390             Yanick                     UMP
# 124391           Philippe                     UMP
# 124392            Tatiana                     SOC
#
#         Nombre de voix du candidat
# 0                                                     142
# 1                                                     175
# 2                                                      56
# 3                                                      66
# 4                                                     286
# ...                                                   ...
# 124388                                                 32
# 124389                                                 35
# 124390                                                 36
# 124391                                                116
# 124392                                                 62
#
# [124393 rows x 14 columns]

# %%
# Inner Join
df_INNER_JOIN = pd.merge(df_geo, df_votes, on=['commune_code','N° de bureau de vote'])

df_INNER_JOIN.to_excel('EXCEL/Les tendances de votes avec cordonnées pour les législatives (2eme tour de 2012).xlsx')

# %%
df_INNER_JOIN = pd.read_excel('EXCEL/Les tendances de votes avec cordonnées pour les législatives (2eme tour de 2012).xlsx')

# %%
df=df_INNER_JOIN.groupby(['commune_code', 'N° de bureau de vote'])['Nombre de voix du candidat'].idxmax()
# df_votes.groupby(['Code Commune (Insee Code)', 'N° de bureau de vote'])['Nombre de voix du candidat'].max()

list_index_le_plus_vote=df.to_frame()['Nombre de voix du candidat'].tolist()


df_le_plus_vote= pd.DataFrame(df_INNER_JOIN,
                  index=list_index_le_plus_vote)

df
# Out:
# commune_code  N° de bureau de vote
# 1001          1                           1
# 1002          1                           3
# 1004          1                           4
#               2                           7
#               3                           9
#                                       ...
# 95680         11                      97841
#               12                      97843
#               13                      97845
# 95682         1                       97848
# 95690         1                       97849
# Name: Nombre de voix du candidat, Length: 47761, dtype: int64

# %%
df_le_plus_vote.to_excel('DataFrame pour les législatives (2eme tour de 2012)/[Pandas] 1,2/df_le_plus_vote.xlsx')
