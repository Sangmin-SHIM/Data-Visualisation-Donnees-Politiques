# %%
import pandas as pd

# %%
excel_final=pd.ExcelFile('Les tendances de votes avec cordonnées pour les législatives (1er tour de 2017).xlsx')

# %%
df_commune = pd.read_excel(excel_final)

# %%
df_commune
# Out:
#        Unnamed: 0  Unnamed: 0.1  commune_code                  libelle  \
# 0               0             0          1001  L'Abergement-Clémenciat
# 1               1             1          1002    L'Abergement-de-Varey
# 2               2             2          1004        Ambérieu-en-Bugey
# 3               3             3          1004        Ambérieu-en-Bugey
# 4               4             4          1004        Ambérieu-en-Bugey
# ...           ...           ...           ...                      ...
# 55008       55008         58413         95680          Villiers-le-Bel
# 55009       55009         58414         95680          Villiers-le-Bel
# 55010       55010         58415         95680          Villiers-le-Bel
# 55011       55011         58416         95682          Villiers-le-Sec
# 55012       55012         58417         95690      Wy-dit-Joli-Village
#
#       Code du b.vote                                          libelle.1  \
# ...

# %%
len(df_commune[df_commune['Unnamed: 221'].notnull()].index.tolist())
# Out:
# 0

# %%
# % Voix/Ins ~ Voix/Ins.26 -> 27


# df_commune[df_commune['% Voix/Ins.11.1'].notnull()].index.tolist()
# 31295 ~ 31778
# len(df_commune[df_commune['% Voix/Ins.4.1'].notnull()].index)

# ################# #
# Make 18 DataFrame #
# ################# #

# ###################################################################################
# (1) % Voix/Ins.11.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.11.1'].notnull()].index.tolist()
# df_voix_11_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_11_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_11_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# 3) Make Excel File
# df_voix_11_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_11_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (2) % Voix/Ins.10.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.10.1'].notnull()].index.tolist()
# df_voix_10_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_10_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_10_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# 3) Make Excel File
# df_voix_10_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_10_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (3) % Voix/Ins.9.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.9.1'].notnull()].index.tolist()
# df_voix_9_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_9_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_9_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# 3) Make Excel File
# df_voix_9_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_9_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (4) % Voix/Ins.8.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.8.1'].notnull()].index.tolist()
# df_voix_8_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_8_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_8_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# 3) Make Excel File
# df_voix_8_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_8_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (5) % Voix/Ins.7.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.7.1'].notnull()].index.tolist()
# df_voix_7_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_7_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_7_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# 3) Make Excel File
# df_voix_7_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_7_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (6) % Voix/Ins.6.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.6.1'].notnull()].index.tolist()
# df_voix_6_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_6_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_6_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# 3) Make Excel File
# df_voix_6_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_6_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (7) % Voix/Ins.5.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.5.1'].notnull()].index.tolist()
# df_voix_5_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_5_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_5_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_5_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_5_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (8) % Voix/Ins.4.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.4.1'].notnull()].index.tolist()
# df_voix_4_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_4_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_4_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_4_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_4_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (9) % Voix/Ins.3.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.3.1'].notnull()].index.tolist()
# df_voix_3_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_3_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_3_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_3_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_3_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (10) % Voix/Ins.2.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.2.1'].notnull()].index.tolist()
# df_voix_2_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_2_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_2_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_2_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_2_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (11) % Voix/Ins.1.1

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.1.1'].notnull()].index.tolist()
# df_voix_1_1 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_1_1
# ----------------------------
# df = pd.concat([df_commune, df_voix_1_1])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_1_1.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_1_1.xlsx')

# And Then Block those four lines

# ###################################################################################
# (12) % Voix/Ins.13

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.13'].notnull()].index.tolist()
# df_voix_13 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_13
# ----------------------------
# df = pd.concat([df_commune, df_voix_13])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_13.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_13.xlsx')

# And Then Block those four lines

# ###################################################################################
# (13) % Voix/Ins.12

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.12'].notnull()].index.tolist()
# df_voix_12 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_12
# ----------------------------
# df = pd.concat([df_commune, df_voix_12])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_12.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_12.xlsx')

# And Then Block those four lines

# ###################################################################################
# (14) % Voix/Ins.11

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.11'].notnull()].index.tolist()
# df_voix_11 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_11
# ----------------------------
# df = pd.concat([df_commune, df_voix_11])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_11.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_11.xlsx')

# And Then Block those four lines

# ###################################################################################
# (15) % Voix/Ins.10

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.10'].notnull()].index.tolist()
# df_voix_10 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_10
# ----------------------------
# df = pd.concat([df_commune, df_voix_10])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_10.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_10.xlsx')

# And Then Block those four lines

# ###################################################################################
# (16) % Voix/Ins.9

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.9'].notnull()].index.tolist()
# df_voix_9 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_9
# ----------------------------
# df = pd.concat([df_commune, df_voix_9])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_9.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_9.xlsx')

# And Then Block those four lines

# ###################################################################################
# (17) % Voix/Ins.8

# 1) Make a new DataFrame 
# -----------------------
# index_list = df_commune[df_commune['% Voix/Ins.8'].notnull()].index.tolist()
# df_voix_8 = pd.DataFrame(df_commune, index=index_list)

# And Then Block those two lines

# 2) df_commune - df_voix_8
# ----------------------------
# df = pd.concat([df_commune, df_voix_8])
# df = df.drop_duplicates(keep=False)
# df_commune = df

# # 3) Make Excel File
# df_voix_8.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_8.xlsx')

# And Then Block those four lines

# ###################################################################################
# (18) % Voix/Ins.7 ~ % Voix/Ins

# Make Excel File
# df_commune.to_excel('DataFrame pour les législatives (1er tour de 2017)/df_voix_7_to_0.xlsx')
# Out:
# []

# %%
import folium
from folium.plugins import FastMarkerCluster

map = folium.Map(location=[46.91160617052484, 2.153649265809747]
                       , zoom_start=5.5)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
