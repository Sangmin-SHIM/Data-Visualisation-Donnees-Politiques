# %%
import pandas as pd

# %%
excel_final=pd.ExcelFile('DataFrame pour les législatives (2eme tour de 2007)/Les tendances de votes avec cordonnées pour les législatives (2eme tour de 2007)_final.xlsx')

# %%
df_commune = pd.read_excel(excel_final)

# %%
df_commune
# Out:
#        commune_code N° de bureau de vote  longitude   latitude  Inscrits  \
# 0              1006                    1   5.601976  45.751418       113
# 1              1009                    1   5.658082  45.801272       267
# 2              1010                    1   5.809112  45.913543       592
# 3              1012                    1   5.508168  46.003122       278
# 4              1013                    1   5.485878  45.896684       153
# ...             ...                  ...        ...        ...       ...
# 38869         95680                    8   2.412123  48.999556       522
# 38870         95680                    9   2.395384  49.003751      1420
# 38871         95680                   10   2.395384  49.003751      1003
# 38872         95682                    1   2.390021  49.072537        97
# 38873         95690                    1   1.835615  49.102958       258
#
#        Votants  Exprimés Nom du candidat Prénom du candidat  \
# ...

# %%
df_commune[df_commune['% Voix/Exp'].notnull()]
# Out:
#        commune_code N° de bureau de vote  longitude   latitude  Inscrits  \
# 22407         59002                    1   3.299619  50.333323       958
# 22408         59002                    2   3.299619  50.333323       958
# 22409         59002                    3   3.299619  50.333323       980
# 22489         59019                    1   3.540886  50.294304       796
# 22507         59032                    1   3.528971  50.331320      1169
# ...             ...                  ...        ...        ...       ...
# 37186         93048                   41   2.432709  48.865829      1072
# 37187         93048                   42   2.432709  48.865829      1128
# 37188         93048                   43   2.432709  48.865829       863
# 37189         93048                   44   2.433889  48.868430      1199
# 37190         93048                   45   2.464720  48.874810       914
#
#        Votants  Exprimés Nom du candidat Prénom du candidat  \
# ...

# %%
# number = 3,2,1,0

def makeDataFrame(number):
    global df_commune
    
    # 1) Make a new DataFrame 
    index_list = df_commune[df_commune['Nom du candidat.'+str(number)].notnull()].index.tolist()
    globals()['df_voix_'+str(number)] = pd.DataFrame(df_commune, index=index_list)
    
    # 2) df_commune - df_new_dataframe
    df = pd.concat([df_commune, globals()['df_voix_'+str(number)]])
    df = df.drop_duplicates(keep=False)
    df_commune = df
    
    # 3) Make Excel File
    globals()['df_voix_'+str(number)].to_excel('DataFrame pour les législatives (2eme tour de 2007)/df_voix_'+str(number)+'.xlsx')

# %%
for number in range(3,-1,-1):
    if number == 0:
        df_commune.to_excel('DataFrame pour les législatives (2eme tour de 2007)/df_voix_0.xlsx')
        break
    makeDataFrame(number)
