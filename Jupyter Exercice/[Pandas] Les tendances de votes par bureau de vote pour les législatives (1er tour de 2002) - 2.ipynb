# %%
import pandas as pd

# %%
# Open EXCEL/Les tendances de votes par bureau de vote pour les législatives (1er tour de 2002).xlsx
# Make a candidates list horizontally MANUALLY DIRECTLY in excel file with function IF & AND
# Then Save as like that
excel_bureaux_de_vote=pd.ExcelFile('DataFrame pour les législatives (1er tour de 2002)/[Pandas] 1,2/1) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_candidates_list.xlsx')

# %%
df_commune = pd.read_excel(excel_bureaux_de_vote)

# %%
df_commune
# Out:
#         commune_code  N° de bureau de vote                  libelle  \
# 0               1001                   1.0  L'Abergement-Clémenciat
# 1               1001                   1.0  L'Abergement-Clémenciat
# 2               1001                   1.0  L'Abergement-Clémenciat
# 3               1001                   1.0  L'Abergement-Clémenciat
# 4               1001                   1.0  L'Abergement-Clémenciat
# ...              ...                   ...                      ...
# 680441         95690                   1.0      Wy-dit-Joli-Village
# 680442         95690                   1.0      Wy-dit-Joli-Village
# 680443         95690                   1.0      Wy-dit-Joli-Village
# 680444         95690                   1.0      Wy-dit-Joli-Village
# 680445         95690                   1.0      Wy-dit-Joli-Village
#
#         longitude   latitude  Inscrits  Votants  Exprimés  \
# 0        4.920902  46.150784       568      356       349
# ...

# %%
# Here nth(-1) : last
df_groupby_last=df_commune.groupby(['commune_code', 'N° de bureau de vote','longitude','latitude','Inscrits','Votants','Exprimés'])[['Nom du candidat','Prénom du candidat','Code nuance du candidat ','Nombre de voix du candidat','% Voix/Exp','list_candidates']].nth(-1)

# %%
df_groupby_last
# Out:
#                                                                                 Nom du candidat  \
# commune_code N° de bureau de vote longitude latitude  Inscrits Votants Exprimés
# 1001         1.0                  4.920902  46.150784 568      356     349            DOMMANGET
# 1002         1.0                  5.423436  46.007249 195      151     151             KALLACHE
# 1004         1.0                  5.348146  45.960048 1393     846     837             KALLACHE
#              2.0                  5.348146  45.960048 1513     929     920             KALLACHE
#              3.0                  5.364613  45.955227 1328     720     704             KALLACHE
# ...                                                                                         ...
# 95680        8.0                  2.412123  48.999556 470      293     288                MOIGN
#              9.0                  2.395384  49.003751 1117     527     514                MOIGN
# ...

# %%
# For get the information of candidates horizontally, we save df_groupby_last. And then, Manually we abstract and make the candidates list (CSV)
df_groupby_last.to_excel('DataFrame pour les législatives (1er tour de 2002)/[Pandas] 1,2/2)Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_groupby_last.xlsx')

# %%
# candidates.txt (abstracted manually from 'Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_groupby_last.xlsx')
# -> 4)candidates.xlsx (or .txt)

# %%
df_modified=df_commune.groupby(['commune_code', 'N° de bureau de vote','longitude','latitude','Inscrits','Votants','Exprimés'])[['Nom du candidat','Prénom du candidat','Code nuance du candidat ','Nombre de voix du candidat','% Voix/Exp']].first()
df_modified
df_modified.to_excel('DataFrame pour les législatives (1er tour de 2002)/[Pandas] 1,2/3) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_groupby_first.xlsx')

# %%
# 3) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_groupby_first.xlsx
# 4) candidates.xlsx (or .txt)
# Add Manually

# Save as Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_final_before_MAX.xlsx

# %%
excel_votes_bureaux_de_vote_final = pd.ExcelFile('DataFrame pour les législatives (1er tour de 2002)/[Pandas] 1,2/5) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_final_before_MAX.xlsx')

# %%
# Inner Join 
# 'tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_final.xlsx'
# 'df_le_plus_vote.xlsx'
# Add le plus voté as column in tendances de votes avec cordonnées pour les législatives (2eme tour de 2007)_final

# %%
excel_le_plus_vote=pd.ExcelFile('DataFrame pour les législatives (1er tour de 2002)/[Pandas] 1,2/df_le_plus_vote.xlsx')

# %%
df_votes_final=pd.read_excel(excel_votes_bureaux_de_vote_final)
df_le_plus_vote=pd.read_excel(excel_le_plus_vote)

# %%
df_INNER_JOIN = pd.merge(df_votes_final,df_le_plus_vote, on=['commune_code','N° de bureau de vote'])

df_INNER_JOIN
# Out:
#        commune_code  N° de bureau de vote  longitude_x  latitude_x  \
# 0              1001                   1.0     4.920902   46.150784
# 1              1002                   1.0     5.423436   46.007249
# 2              1004                   1.0     5.348146   45.960048
# 3              1004                   2.0     5.348146   45.960048
# 4              1004                   3.0     5.364613   45.955227
# ...             ...                   ...          ...         ...
# 47900         95680                   8.0     2.412123   48.999556
# 47901         95680                   9.0     2.395384   49.003751
# 47902         95680                  10.0     2.395384   49.003751
# 47903         95682                   1.0     2.390021   49.072537
# 47904         95690                   1.0     1.835615   49.102958
#
#        Inscrits_x  Votants_x  Exprimés_x Nom du candidat_x  \
# 0             568        356         349   LACHEISSERIE DE
# ...

# %%
df_INNER_JOIN.to_excel('DataFrame pour les législatives (1er tour de 2002)/Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002)_final.xlsx')
