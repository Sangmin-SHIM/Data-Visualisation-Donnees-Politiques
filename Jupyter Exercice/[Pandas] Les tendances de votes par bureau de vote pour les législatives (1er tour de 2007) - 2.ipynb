# %%
import pandas as pd

# %%
# Open EXCEL/Les tendances de votes par bureau de vote pour les législatives (1er tour de 2007).xlsx and Then With Excel Function
# Make a candidates list horizontally manually directly in excel file with function IF & AND
# Then Save as like that
excel_bureaux_de_vote=pd.ExcelFile('DataFrame pour les législatives (1er tour de 2007)/[Pandas] 1,2/1) Les tendances de votes par bureau de vote pour les législatives (1er tour de 2007)_candidates_list.xlsx')

# %%
df_commune = pd.read_excel(excel_bureaux_de_vote)

# %%
df_commune
# Out:
#         commune_code N° de bureau de vote                  libelle  longitude  \
# 0               1001                    1  L'Abergement-Clémenciat   4.920902
# 1               1001                    1  L'Abergement-Clémenciat   4.920902
# 2               1001                    1  L'Abergement-Clémenciat   4.920902
# 3               1001                    1  L'Abergement-Clémenciat   4.920902
# 4               1001                    1  L'Abergement-Clémenciat   4.920902
# ...              ...                  ...                      ...        ...
# 653162         95690                    1      Wy-dit-Joli-Village   1.835615
# 653163         95690                    1      Wy-dit-Joli-Village   1.835615
# 653164         95690                    1      Wy-dit-Joli-Village   1.835615
# 653165         95690                    1      Wy-dit-Joli-Village   1.835615
# 653166         95690                    1      Wy-dit-Joli-Village   1.835615
#
# ...

# %%
# Here nth(-1)
df_groupby_last=df_commune.groupby(['commune_code', 'N° de bureau de vote','longitude','latitude','Inscrits','Votants','Exprimés'])[['Nom du candidat','Prénom du candidat','Code nuance du candidat','Nombre de voix du candidat','% Voix/Exp','candidat_list']].nth(-1)

# %%
df_groupby_last
# Out:
#                                                                                 Nom du candidat  \
# commune_code N° de bureau de vote longitude latitude  Inscrits Votants Exprimés
# 1001         1                    4.920902  46.150784 598      353     347                VACLE
# 1002         1                    5.423436  46.007249 205      146     145            FERRARESE
# 1004         1                    5.348146  45.960048 1079     556     546            FERRARESE
#              2                    5.348146  45.960048 921      452     446            FERRARESE
#              3                    5.364613  45.955227 959      491     486            FERRARESE
# ...                                                                                         ...
# 95680        8                    2.412123  48.999556 522      288     280               CADIOT
#              9                    2.395384  49.003751 1420     646     632               CADIOT
# ...

# %%
# For get the information of candidates horizontally, we save df_groupby_last. And then, Manually we abstract and make the candidates list (CSV)
df_groupby_last.to_excel('DataFrame pour les législatives (1er tour de 2007)/[Pandas] 1,2/2)Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_groupby_last.xlsx')

# %%
# candidates.txt (abstracted manually from 'Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_groupby_last.xlsx')
# -> 4)candidates.xlsx (or .txt)

# %%
df_modified=df_commune.groupby(['commune_code', 'N° de bureau de vote','longitude','latitude','Inscrits','Votants','Exprimés'])[['Nom du candidat','Prénom du candidat','Code nuance du candidat','Nombre de voix du candidat','% Voix/Exp']].first()
df_modified
df_modified.to_excel('DataFrame pour les législatives (1er tour de 2007)/[Pandas] 1,2/3) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_groupby_first.xlsx')

# %%
# 3) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_groupby_first.xlsx
# 4) candidates.xlsx (or .txt)
# Add Manually

# Save as Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_final.xlsx

# %%
# Inner Join 
# 'tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_final.xlsx'
# 'df_le_plus_vote.xlsx'
# Add le plus voté as column in tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_final

# %%
excel_votes_bureaux_de_vote_final = pd.ExcelFile('DataFrame pour les législatives (1er tour de 2007)/[Pandas] 1,2/5) Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_final_before_MAX.xlsx')

# %%
excel_le_plus_vote=pd.ExcelFile('DataFrame pour les législatives (1er tour de 2007)/[Pandas] 1,2/df_le_plus_vote.xlsx')

# %%
df_votes_final=pd.read_excel(excel_votes_bureaux_de_vote_final)
df_le_plus_vote=pd.read_excel(excel_le_plus_vote)

# %%
df_INNER_JOIN = pd.merge(df_votes_final,df_le_plus_vote, on=['commune_code','N° de bureau de vote'])

df_INNER_JOIN
# Out:
#        commune_code N° de bureau de vote  longitude_x  latitude_x  Inscrits_x  \
# 0              1001                    1     4.920902   46.150784         598
# 1              1002                    1     5.423436   46.007249         205
# 2              1004                    1     5.348146   45.960048        1079
# 3              1004                    2     5.348146   45.960048         921
# 4              1004                    3     5.364613   45.955227         959
# ...             ...                  ...          ...         ...         ...
# 49531         95680                    8     2.412123   48.999556         522
# 49532         95680                    9     2.395384   49.003751        1420
# 49533         95680                   10     2.395384   49.003751        1003
# 49534         95682                    1     2.390021   49.072537          97
# 49535         95690                    1     1.835615   49.102958         258
#
# ...

# %%
df_INNER_JOIN.to_excel('DataFrame pour les législatives (1er tour de 2007)/Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007)_final.xlsx')
