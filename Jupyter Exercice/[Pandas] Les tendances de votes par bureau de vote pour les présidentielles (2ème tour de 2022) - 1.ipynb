# %%
import pandas as pd

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('EXCEL/geo_bureaux_de_vote_md.xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
df_geo
# Out:
#       commune_code                  libelle code                  libelle.1  \
# 0             1001  L'Abergement-Clémenciat    1                   Bureau 1
# 1             1002    L'Abergement-de-Varey    1                     Mairie
# 2             1004        Ambérieu-en-Bugey    1           B1 - ESPACE 1500
# 3             1004        Ambérieu-en-Bugey    2           B2 - ESPACE 1500
# 4             1004        Ambérieu-en-Bugey    3  B3 - Château des Echelles
# ...            ...                      ...  ...                        ...
# 60566        2B352          Ville-di-Paraso    1        Bureau de Vote N° 1
# 60567        2B353     Ville-di-Pietrabugno    1                     MAIRIE
# 60568        2B353     Ville-di-Pietrabugno    2              MAISON DU CAP
# 60569        2B354                  Vivario    1           Salle de réunion
# 60570        2B355                Volpajola    2         Ecole de Barchetta
#
# ...

# %%
excel_votes_bureaux_de_vote = pd.ExcelFile('EXCEL/Les tendances de votes par bureau de vote pour les présidentielles (2ème tour de 2022).xlsx')

# %%
df_votes = pd.read_excel(excel_votes_bureaux_de_vote)

# %%
df_votes
# Out:
#       commune_code           Libellé du département  \
# 0             1001                              Ain
# 1             1002                              Ain
# 2             1004                              Ain
# 3             1004                              Ain
# 4             1004                              Ain
# ...            ...                              ...
# 69677           ZZ  Français établis hors de France
# 69678           ZZ  Français établis hors de France
# 69679           ZZ  Français établis hors de France
# 69680           ZZ  Français établis hors de France
# 69681           ZZ  Français établis hors de France
#
#        Code de la circonscription Libellé de la circonscription  \
# 0                               4          4ème circonscription
# 1                               5          5ème circonscription
# 2                               5          5ème circonscription
# 3                               5          5ème circonscription
# ...

# %%
df_geo.rename(columns={'code':'Code du b.vote'}, inplace=True)
#df_votes.rename(columns={'Code du département':'commune_code'}, inplace=True)

# %%
# Inner Join
df_INNER_JOIN = pd.merge(df_geo, df_votes, on=['commune_code','Code du b.vote'])

# %%
df_INNER_JOIN.to_excel('EXCEL/Les tendances de votes avec cordonnées pour les présidentielles (2ème tour de 2022).xlsx')

# %%
df_INNER_JOIN
# Out:
#       commune_code                  libelle Code du b.vote  \
# 0             1001  L'Abergement-Clémenciat              1
# 1             1002    L'Abergement-de-Varey              1
# 2             1004        Ambérieu-en-Bugey              1
# 3             1004        Ambérieu-en-Bugey              2
# 4             1004        Ambérieu-en-Bugey              3
# ...            ...                      ...            ...
# 55013        95680          Villiers-le-Bel             11
# 55014        95680          Villiers-le-Bel             12
# 55015        95680          Villiers-le-Bel             13
# 55016        95682          Villiers-le-Sec              1
# 55017        95690      Wy-dit-Joli-Village              1
#
#                                                libelle.1 code_postal  \
# 0                                               Bureau 1        1400
# 1                                                 Mairie        1640
# ...
