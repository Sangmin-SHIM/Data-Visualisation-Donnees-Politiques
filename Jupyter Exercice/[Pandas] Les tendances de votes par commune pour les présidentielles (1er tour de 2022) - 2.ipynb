# %%
import pandas as pd

# %%
excel_final=pd.ExcelFile('EXCEL/Les tendances de votes avec cordonnées pour les présidentielles (1er tour de 2022).xlsx')

# %%
df_commune = pd.read_excel(excel_final)

# %%
df_commune
# Out:
#       commune_code Code du département         Libellé du département  \
# 0             1001                1000                            Ain
# 1             1002                1000                            Ain
# 2             1004                1000                            Ain
# 3             1005                1000                            Ain
# 4             1006                1000                            Ain
# ...            ...                 ...                            ...
# 35030        ZS501                  ZS       Saint-Pierre-et-Miquelon
# 35031        ZS502                  ZS       Saint-Pierre-et-Miquelon
# 35032        ZW001                  ZW               Wallis et Futuna
# 35033        ZX701                  ZX  Saint-Martin/Saint-Barthélemy
# 35034        ZX801                  ZX  Saint-Martin/Saint-Barthélemy
#
#        Code de la commune    Libellé de la commune Etat saisie  Inscrits  \
# 0                       1  L'Abergement-Clémenciat     Complet       645
# 1                       2    L'Abergement-de-Varey     Complet       213
# 2                       4        Ambérieu-en-Bugey     Complet      8765
# 3                       5      Ambérieux-en-Dombes     Complet      1282
# 4                       6                  Ambléon     Complet       103
# ...                   ...                      ...         ...       ...
# 35030                 501        Miquelon-Langlade     Complet       504
# 35031                 502             Saint-Pierre     Complet      4541
# 35032                   1         Wallis-Et-Futuna     Complet      9528
# 35033                 701         Saint-Barthélémy     Complet      5267
# 35034                 801             Saint-Martin     Complet     19147
#
#        Abstentions  % Abs/Ins  Votants  ...  Voix.10  % Voix/Ins.10  \
# 0              108      16.74      537  ...        3           0.47
# 1               38      17.84      175  ...        3           1.41
# 2             2078      23.71     6687  ...       43           0.49
# 3              234      18.25     1048  ...        2           0.16
# 4               23      22.33       80  ...        0           0.00
# ...            ...        ...      ...  ...      ...            ...
# 35030          268      53.17      236  ...        2           0.40
# 35031         2004      44.13     2537  ...       48           1.06
# 35032         4125      43.29     5403  ...       48           0.50
# 35033         2563      48.66     2704  ...       27           0.51
# 35034        13249      69.20     5898  ...       36           0.19
#
#        % Voix/Exp.10  N°Panneau.11  Sexe.11         Nom.11  Prénom.11  \
# 0               0.58            12        M  DUPONT-AIGNAN    Nicolas
# 1               1.75            12        M  DUPONT-AIGNAN    Nicolas
# 2               0.66            12        M  DUPONT-AIGNAN    Nicolas
# 3               0.19            12        M  DUPONT-AIGNAN    Nicolas
# 4               0.00            12        M  DUPONT-AIGNAN    Nicolas
# ...              ...           ...      ...            ...        ...
# 35030           0.86            12        M  DUPONT-AIGNAN    Nicolas
# 35031           1.94            12        M  DUPONT-AIGNAN    Nicolas
# 35032           0.90            12        M  DUPONT-AIGNAN    Nicolas
# 35033           1.02            12        M  DUPONT-AIGNAN    Nicolas
# 35034           0.63            12        M  DUPONT-AIGNAN    Nicolas
#
#        Voix.11  % Voix/Ins.11  % Voix/Exp.11
# 0           21           3.26           4.04
# 1            0           0.00           0.00
# 2          181           2.07           2.76
# 3           27           2.11           2.63
# 4            1           0.97           1.30
# ...        ...            ...            ...
# 35030        9           1.79           3.88
# 35031       73           1.61           2.96
# 35032      244           2.56           4.55
# 35033      169           3.21           6.40
# 35034      170           0.89           2.97
#
# [35035 rows x 104 columns]

# %%
# Le Plus Voté - Nom, Prénom et % Voix / Ins
# ------------------------------------------

df_voix_exp = df_commune[['% Voix/Exp', '% Voix/Exp.1', '% Voix/Exp.2' , '% Voix/Exp.3' , '% Voix/Exp.4' , '% Voix/Exp.5' , '% Voix/Exp.6' , '% Voix/Exp.7', '% Voix/Exp.8', '% Voix/Exp.9', '% Voix/Exp.10', '% Voix/Exp.11']]

class Candidat:
    def __init__(self, nom, prenom):
        self.nom = nom
        self.prenom = prenom

candidat=[]

candidat.append(Candidat('ARTHAUD','Nathalie'))
for i in range(2,13):
    candidat.append(Candidat(df_commune["Nom."+str(i-1)][0], df_commune["Prénom."+str(i-1)][0]))

df_commune['NOM_candidat_le_plus_voté']=df_voix_exp.idxmax(axis=1).str.replace('% Voix/Exp','Nom')
df_commune['PRENOM_candidat_le_plus_voté']=df_voix_exp.idxmax(axis=1).str.replace('% Voix/Exp','Prénom')

df_commune['% Voix/Exp_le_plus_voté']=df_voix_exp.max(axis=1)

df_commune.loc[(df_commune.NOM_candidat_le_plus_voté =='Nom'),'NOM_candidat_le_plus_voté'] = candidat[0].nom
df_commune.loc[(df_commune.PRENOM_candidat_le_plus_voté =='Prénom'),'PRENOM_candidat_le_plus_voté'] = candidat[0].prenom
for i in range(2,13):
    df_commune.loc[(df_commune.NOM_candidat_le_plus_voté =='Nom.'+str(i-1),'NOM_candidat_le_plus_voté')] = candidat[i-1].nom
    df_commune.loc[(df_commune.PRENOM_candidat_le_plus_voté =='Prénom.'+str(i-1),'PRENOM_candidat_le_plus_voté')] = candidat[i-1].prenom


# df.loc[(df.Event == 'Dance'),'Event']='Hip-Hop'


# Excel Change !
df_commune.to_excel('EXCEL/Les tendances de votes avec cordonnées pour les présidentielles (1er tour de 2022).xlsx')

# %%
df_commune
# Out:
#       commune_code Code du département         Libellé du département  \
# 0             1001                1000                            Ain
# 1             1002                1000                            Ain
# 2             1004                1000                            Ain
# 3             1005                1000                            Ain
# 4             1006                1000                            Ain
# ...            ...                 ...                            ...
# 35030        ZS501                  ZS       Saint-Pierre-et-Miquelon
# 35031        ZS502                  ZS       Saint-Pierre-et-Miquelon
# 35032        ZW001                  ZW               Wallis et Futuna
# 35033        ZX701                  ZX  Saint-Martin/Saint-Barthélemy
# 35034        ZX801                  ZX  Saint-Martin/Saint-Barthélemy
#
#        Code de la commune    Libellé de la commune Etat saisie  Inscrits  \
# 0                       1  L'Abergement-Clémenciat     Complet       645
# 1                       2    L'Abergement-de-Varey     Complet       213
# 2                       4        Ambérieu-en-Bugey     Complet      8765
# 3                       5      Ambérieux-en-Dombes     Complet      1282
# 4                       6                  Ambléon     Complet       103
# ...                   ...                      ...         ...       ...
# 35030                 501        Miquelon-Langlade     Complet       504
# 35031                 502             Saint-Pierre     Complet      4541
# 35032                   1         Wallis-Et-Futuna     Complet      9528
# 35033                 701         Saint-Barthélémy     Complet      5267
# 35034                 801             Saint-Martin     Complet     19147
#
#        Abstentions  % Abs/Ins  Votants  ...  N°Panneau.11  Sexe.11  \
# 0              108      16.74      537  ...            12        M
# 1               38      17.84      175  ...            12        M
# 2             2078      23.71     6687  ...            12        M
# 3              234      18.25     1048  ...            12        M
# 4               23      22.33       80  ...            12        M
# ...            ...        ...      ...  ...           ...      ...
# 35030          268      53.17      236  ...            12        M
# 35031         2004      44.13     2537  ...            12        M
# 35032         4125      43.29     5403  ...            12        M
# 35033         2563      48.66     2704  ...            12        M
# 35034        13249      69.20     5898  ...            12        M
#
#               Nom.11  Prénom.11  Voix.11  % Voix/Ins.11  % Voix/Exp.11  \
# 0      DUPONT-AIGNAN    Nicolas       21           3.26           4.04
# 1      DUPONT-AIGNAN    Nicolas        0           0.00           0.00
# 2      DUPONT-AIGNAN    Nicolas      181           2.07           2.76
# 3      DUPONT-AIGNAN    Nicolas       27           2.11           2.63
# 4      DUPONT-AIGNAN    Nicolas        1           0.97           1.30
# ...              ...        ...      ...            ...            ...
# 35030  DUPONT-AIGNAN    Nicolas        9           1.79           3.88
# 35031  DUPONT-AIGNAN    Nicolas       73           1.61           2.96
# 35032  DUPONT-AIGNAN    Nicolas      244           2.56           4.55
# 35033  DUPONT-AIGNAN    Nicolas      169           3.21           6.40
# 35034  DUPONT-AIGNAN    Nicolas      170           0.89           2.97
#
#        NOM_candidat_le_plus_voté  PRENOM_candidat_le_plus_voté  \
# 0                         MACRON                      Emmanuel
# 1                         MACRON                      Emmanuel
# 2                         LE PEN                        Marine
# 3                         LE PEN                        Marine
# 4                         MACRON                      Emmanuel
# ...                          ...                           ...
# 35030                  MÉLENCHON                      Jean-Luc
# 35031                  MÉLENCHON                      Jean-Luc
# 35032                     MACRON                      Emmanuel
# 35033                     MACRON                      Emmanuel
# 35034                  MÉLENCHON                      Jean-Luc
#
#        % Voix/Exp_le_plus_voté
# 0                        28.85
# 1                        29.24
# 2                        25.12
# 3                        34.24
# 4                        27.27
# ...                        ...
# 35030                    34.05
# 35031                    41.56
# 35032                    39.47
# 35033                    23.81
# 35034                    35.03
#
# [35035 rows x 107 columns]

# %%
# df_commune
# df_voix_exp.idxmax(axis=1).str.replace('% Voix/Exp','Nom')
df_voix_exp.max(axis=1)
# Out:
# 0        28.85
# 1        29.24
# 2        25.12
# 3        34.24
# 4        27.27
#          ...
# 35030    34.05
# 35031    41.56
# 35032    39.47
# 35033    23.81
# 35034    35.03
# Length: 35035, dtype: float64
