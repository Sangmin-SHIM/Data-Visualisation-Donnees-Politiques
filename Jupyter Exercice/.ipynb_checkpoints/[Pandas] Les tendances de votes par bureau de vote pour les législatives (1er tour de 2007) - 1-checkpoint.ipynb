# %%
import pandas as pd

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('EXCEL/geo_bureaux_de_vote_md.xlsx')

# %%
# To make thie excel file, we have to make a candidates list by 'commune code' and 'code bureau de vote' manually using excel function
excel_votes_bureaux_de_vote = pd.ExcelFile('EXCEL/Les tendances de votes par bureau de vote pour les législatives (1er tour de 2007).xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
df_votes = pd.read_excel(excel_votes_bureaux_de_vote)

# %%
df_geo.rename(columns={'code':'N° de bureau de vote'}, inplace=True)
df_geo
# Out:
#        Unnamed: 0 commune_code                  libelle N° de bureau de vote  \
# 0               0         1001  L'Abergement-Clémenciat                    1
# 1               1         1002    L'Abergement-de-Varey                    1
# 2               2         1004        Ambérieu-en-Bugey                    1
# 3               3         1004        Ambérieu-en-Bugey                    2
# 4               4         1004        Ambérieu-en-Bugey                    3
# ...           ...          ...                      ...                  ...
# 60566       60569        2B352          Ville-di-Paraso                    1
# 60567       60570        2B353     Ville-di-Pietrabugno                    1
# 60568       60571        2B353     Ville-di-Pietrabugno                    2
# 60569       60572        2B354                  Vivario                    1
# 60570       60573        2B355                Volpajola                    2
#
#                        libelle.1 code_postal                commune  \
# 0                       Bureau 1        1400  ABERGEMENT CLEMENCIAT
# 1                         Mairie        1640  L'ABERGEMENT DE VAREY
# 2               B1 - ESPACE 1500        1500      AMBERIEU-EN-BUGEY
# 3               B2 - ESPACE 1500        1500      AMBERIEU-EN-BUGEY
# 4      B3 - Château des Echelles        1500      AMBERIEU-EN-BUGEY
# ...                          ...         ...                    ...
# 60566        Bureau de Vote N° 1       20279        VILLE DI PARASO
# 60567                     MAIRIE       20200   VILLE-DI-PIETRABUGNO
# 60568              MAISON DU CAP       20200   VILLE-DI-PIETRABUGNO
# 60569           Salle de réunion       20219                VIVARIO
# 60570         Ecole de Barchetta       20290              VOLPAJOLA
#
#        longitude   latitude
# 0       4.920902  46.150784
# 1       5.423436  46.007249
# 2       5.348146  45.960048
# 3       5.348146  45.960048
# 4       5.364613  45.955227
# ...          ...        ...
# 60566   8.993626  42.581761
# 60567   9.434536  42.711799
# 60568   9.454526  42.709394
# 60569   9.152516  42.152309
# 60570   9.351963  42.510571
#
# [60571 rows x 9 columns]

# %%
df_votes.rename(columns={'Code INSEE':'commune_code'}, inplace=True)
df_votes
# Out:
#        commune_code N° de bureau de vote        Nom de la commune  Unnamed: 3  \
# 0              1001                    1  L'Abergement-Clémenciat         NaN
# 1              1001                    1  L'Abergement-Clémenciat         NaN
# 2              1001                    1  L'Abergement-Clémenciat         NaN
# 3              1001                    1  L'Abergement-Clémenciat         NaN
# 4              1001                    1  L'Abergement-Clémenciat         NaN
# ...             ...                  ...                      ...         ...
# 843363        95690                    1      Wy-dit-Joli-Village         NaN
# 843364        95690                    1      Wy-dit-Joli-Village         NaN
# 843365        95690                    1      Wy-dit-Joli-Village         NaN
# 843366        95690                    1      Wy-dit-Joli-Village         NaN
# 843367        95690                    1      Wy-dit-Joli-Village         NaN
#
#         Inscrits  Votants  Exprimés  Nom du candidat Prénom du candidat  \
# 0            598      353       347         LE MAOUT              Hervé
# 1            598      353       347           VOISIN             Michel
# 2            598      353       347       MONTESSUIT             Claude
# 3            598      353       347  DE LACHEISSERIE          Jean-Loup
# 4            598      353       347          GREFFET         Christophe
# ...          ...      ...       ...              ...                ...
# 843363       258      191       190           DROLON             Corine
# 843364       258      191       190          APPIANI          Christine
# 843365       258      191       190        CANAVELIS          Alexandra
# 843366       258      191       190        BARBESANT             Daniel
# 843367       258      191       190             PIED          Jean-Yves
#
#        Code nuance du candidat  Nombre de voix du candidat
# 0                          MPF                           7
# 1                          UMP                         179
# 2                          VEC                          10
# 3                           FN                          20
# 4                          SOC                          80
# ...                        ...                         ...
# 843363                     SOC                          32
# 843364                     COM                           3
# 843365                    UDFD                          29
# 843366                     EXD                           0
# 843367                     MPF                           2
#
# [843368 rows x 11 columns]

# %%
# Inner Join
df_INNER_JOIN = pd.merge(df_geo, df_votes, on=['commune_code','N° de bureau de vote'])
# df_INNER_JOIN.to_excel('EXCEL/Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007).xlsx')

# %%
df_INNER_JOIN
# Out:
#         Unnamed: 0 commune_code                  libelle N° de bureau de vote  \
# 0                0         1001  L'Abergement-Clémenciat                    1
# 1                0         1001  L'Abergement-Clémenciat                    1
# 2                0         1001  L'Abergement-Clémenciat                    1
# 3                0         1001  L'Abergement-Clémenciat                    1
# 4                0         1001  L'Abergement-Clémenciat                    1
# ...            ...          ...                      ...                  ...
# 653162       58417        95690      Wy-dit-Joli-Village                    1
# 653163       58417        95690      Wy-dit-Joli-Village                    1
# 653164       58417        95690      Wy-dit-Joli-Village                    1
# 653165       58417        95690      Wy-dit-Joli-Village                    1
# 653166       58417        95690      Wy-dit-Joli-Village                    1
#
#        libelle.1 code_postal                commune  longitude   latitude  \
# 0       Bureau 1        1400  ABERGEMENT CLEMENCIAT   4.920902  46.150784
# 1       Bureau 1        1400  ABERGEMENT CLEMENCIAT   4.920902  46.150784
# 2       Bureau 1        1400  ABERGEMENT CLEMENCIAT   4.920902  46.150784
# 3       Bureau 1        1400  ABERGEMENT CLEMENCIAT   4.920902  46.150784
# 4       Bureau 1        1400  ABERGEMENT CLEMENCIAT   4.920902  46.150784
# ...          ...         ...                    ...        ...        ...
# 653162  Bureau 1       95420    WY-DIT-JOLI-VILLAGE   1.835615  49.102958
# 653163  Bureau 1       95420    WY-DIT-JOLI-VILLAGE   1.835615  49.102958
# 653164  Bureau 1       95420    WY-DIT-JOLI-VILLAGE   1.835615  49.102958
# 653165  Bureau 1       95420    WY-DIT-JOLI-VILLAGE   1.835615  49.102958
# 653166  Bureau 1       95420    WY-DIT-JOLI-VILLAGE   1.835615  49.102958
#
#               Nom de la commune  Unnamed: 3  Inscrits  Votants  Exprimés  \
# 0       L'Abergement-Clémenciat         NaN       598      353       347
# 1       L'Abergement-Clémenciat         NaN       598      353       347
# 2       L'Abergement-Clémenciat         NaN       598      353       347
# 3       L'Abergement-Clémenciat         NaN       598      353       347
# 4       L'Abergement-Clémenciat         NaN       598      353       347
# ...                         ...         ...       ...      ...       ...
# 653162      Wy-dit-Joli-Village         NaN       258      191       190
# 653163      Wy-dit-Joli-Village         NaN       258      191       190
# 653164      Wy-dit-Joli-Village         NaN       258      191       190
# 653165      Wy-dit-Joli-Village         NaN       258      191       190
# 653166      Wy-dit-Joli-Village         NaN       258      191       190
#
#         Nom du candidat Prénom du candidat Code nuance du candidat  \
# 0              LE MAOUT              Hervé                     MPF
# 1                VOISIN             Michel                     UMP
# 2            MONTESSUIT             Claude                     VEC
# 3       DE LACHEISSERIE          Jean-Loup                      FN
# 4               GREFFET         Christophe                     SOC
# ...                 ...                ...                     ...
# 653162           DROLON             Corine                     SOC
# 653163          APPIANI          Christine                     COM
# 653164        CANAVELIS          Alexandra                    UDFD
# 653165        BARBESANT             Daniel                     EXD
# 653166             PIED          Jean-Yves                     MPF
#
#         Nombre de voix du candidat
# 0                                7
# 1                              179
# 2                               10
# 3                               20
# 4                               80
# ...                            ...
# 653162                          32
# 653163                           3
# 653164                          29
# 653165                           0
# 653166                           2
#
# [653167 rows x 18 columns]

# %%
df_INNER_JOIN = pd.read_excel('EXCEL/Les tendances de votes avec cordonnées pour les législatives (1er tour de 2007).xlsx')

# %%
df=df_INNER_JOIN.groupby(['commune_code', 'N° de bureau de vote'])['Nombre de voix du candidat'].idxmax()
# df_votes.groupby(['Code Commune (Insee Code)', 'N° de bureau de vote'])['Nombre de voix du candidat'].max()

list_index_le_plus_vote=df.to_frame()['Nombre de voix du candidat'].tolist()


df_le_plus_vote= pd.DataFrame(df_INNER_JOIN,
                  index=list_index_le_plus_vote)

# %%
df_le_plus_vote.to_excel('DataFrame pour les législatives (1er tour de 2007)/[Pandas] 1,2/df_le_plus_vote.xlsx')

# %%
# df_INNER_JOIN2 -

# %%
df_INNER_JOIN2 = pd.merge(df_votes_final,df_excel_le_plus_vote, on=['commune_code','N° de bureau de vote'])

# %%
df_INNER_JOIN2
# Out:
#        commune_code  N° de bureau de vote  longitude_x  latitude_x  \
# 0              1001                   1.0     4.920902   46.150784
# 1              1002                   1.0     5.423436   46.007249
# 2              1004                   1.0     5.348146   45.960048
# 3              1004                   2.0     5.348146   45.960048
# 4              1004                   3.0     5.364613   45.955227
# ...             ...                   ...          ...         ...
# 51397         95680                  11.0     2.387895   49.006733
# 51398         95680                  12.0     2.415228   49.001856
# 51399         95680                  13.0     2.395384   49.003751
# 51400         95682                   1.0     2.390021   49.072537
# 51401         95690                   1.0     1.835615   49.102958
#
#        Inscrits_x  Votants_x  Exprimés_x Nom du candidat_x  \
# 0             595        370         364           LACROIX
# 1             216        138         133        SOKOLOWSKI
# 2            1029        531         528        SOKOLOWSKI
# 3            1071        589         578        SOKOLOWSKI
# 4            1019        608         601        SOKOLOWSKI
# ...           ...        ...         ...               ...
# 51397        1223        488         473            ATONGA
# 51398         950        438         422            ATONGA
# 51399         658        236         225            ATONGA
# 51400          95         72          72             BLAZY
# 51401         277        186         185          GILIBERT
#
#       Prénom du candidat_x Code nuance du candidat_x  ...  Inscrits_y  \
# 0                Guillaume                       RDG  ...         595
# 1                  Patrick                        FN  ...         216
# 2                  Patrick                        FN  ...        1029
# 3                  Patrick                        FN  ...        1071
# 4                  Patrick                        FN  ...        1019
# ...                    ...                       ...  ...         ...
# 51397               Armand                       VEC  ...        1223
# 51398               Armand                       VEC  ...         950
# 51399               Armand                       VEC  ...         658
# 51400          Jean-Pierre                       SOC  ...          95
# 51401             Brigitte                        FN  ...         277
#
#        Votants_y Exprimés_y N° de dépôt du candidat Nom du candidat_y  \
# 0            370        364                       9            VOISIN
# 1            138        133                      41          EXPOSITO
# 2            531        528                      41          EXPOSITO
# 3            589        578                      48              ABAD
# 4            608        601                      41          EXPOSITO
# ...          ...        ...                     ...               ...
# 51397        488        473                      70           PUPPONI
# 51398        438        422                      70           PUPPONI
# 51399        236        225                      70           PUPPONI
# 51400         72         72                      32             BLAZY
# 51401        186        185                       8          HOUILLON
#
#        Prénom du candidat_y  Code nuance du candidat_y % Voix/Exp_y  \
# 0                    Michel                        UMP    35.439560
# 1                   Josiane                        SOC    34.586466
# 2                   Josiane                        SOC    37.500000
# 3                    Damien                        UMP    34.602076
# 4                   Josiane                        SOC    34.442596
# ...                     ...                        ...          ...
# 51397              François                        SOC    43.128964
# 51398              François                        SOC    48.104265
# 51399              François                        SOC    63.555556
# 51400           Jean-Pierre                        SOC    43.055556
# 51401              Philippe                        UMP    45.945946
#
#       Unnamed: 19 Nombre de voix du candidat_y
# 0             NaN                          129
# 1             NaN                           46
# 2             NaN                          198
# 3             NaN                          200
# 4             NaN                          207
# ...           ...                          ...
# 51397         NaN                          204
# 51398         NaN                          203
# 51399         NaN                          143
# 51400         NaN                           31
# 51401         NaN                           85
#
# [51402 rows x 165 columns]

# %%
df_INNER_JOIN2.to_excel('DataFrame pour les législatives (1er tour de 2012)/3)Les tendances de votes avec cordonnées pour les législatives (1er tour de 2012)_final.xlsx')
