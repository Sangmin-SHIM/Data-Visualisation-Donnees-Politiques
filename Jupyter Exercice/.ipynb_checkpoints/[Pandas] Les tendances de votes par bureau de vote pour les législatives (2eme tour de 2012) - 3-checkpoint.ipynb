# %%
import pandas as pd

# %%
excel_final=pd.ExcelFile('DataFrame pour les législatives (2eme tour de 2012)/Les tendances de votes avec cordonnées pour les législatives (2eme tour de 2012)_final.xlsx')

# %%
df_commune = pd.read_excel(excel_final)

# %%
df_commune
# Out:
#          Unnamed: 0  commune_code  N° de bureau de vote  longitude_x  \
# 0               0.0        1001.0                   1.0     4.920902
# 1               1.0        1002.0                   1.0     5.423436
# 2               2.0        1004.0                   1.0     5.348146
# 3               3.0        1004.0                   2.0     5.348146
# 4               4.0        1004.0                   3.0     5.364613
# ...             ...           ...                   ...          ...
# 1048570         NaN           NaN                   NaN          NaN
# 1048571         NaN           NaN                   NaN          NaN
# 1048572         NaN           NaN                   NaN          NaN
# 1048573         NaN           NaN                   NaN          NaN
# 1048574         NaN           NaN                   NaN          NaN
#
#           latitude  Inscrits  Votants  Exprimés Nom du candidat  \
# 0        46.150784     595.0    330.0     317.0         LACROIX
# 1        46.007249     216.0    130.0     122.0        EXPOSITO
# 2        45.960048    1029.0    536.0     521.0        EXPOSITO
# 3        45.960048    1071.0    608.0     584.0        EXPOSITO
# 4        45.955227    1019.0    588.0     559.0        EXPOSITO
# ...            ...       ...      ...       ...             ...
# 1048570        NaN       NaN      NaN       NaN             NaN
# 1048571        NaN       NaN      NaN       NaN             NaN
# 1048572        NaN       NaN      NaN       NaN             NaN
# 1048573        NaN       NaN      NaN       NaN             NaN
# 1048574        NaN       NaN      NaN       NaN             NaN
#
#         Prénom du candidat  ... Unnamed: 29  Unnamed: 30  Unnamed: 31  \
# 0                Guillaume  ...         NaN          NaN          NaN
# 1                  Josiane  ...         NaN          NaN          NaN
# 2                  Josiane  ...         NaN          NaN          NaN
# 3                  Josiane  ...         NaN          NaN          NaN
# 4                  Josiane  ...         NaN          NaN          NaN
# ...                    ...  ...         ...          ...          ...
# 1048570                NaN  ...         NaN          NaN          NaN
# 1048571                NaN  ...         NaN          NaN          NaN
# 1048572                NaN  ...         NaN          NaN          NaN
# 1048573                NaN  ...         NaN          NaN          NaN
# 1048574                NaN  ...         NaN          NaN          NaN
#
#         Unnamed: 32 Unnamed: 33 NOM_le_plus_voté  PRENOM_le_plus_voté  \
# 0               NaN         NaN           VOISIN               Michel
# 1               NaN         NaN             ABAD               Damien
# 2               NaN         NaN         EXPOSITO              Josiane
# 3               NaN         NaN             ABAD               Damien
# 4               NaN         NaN             ABAD               Damien
# ...             ...         ...              ...                  ...
# 1048570         NaN         NaN              NaN                  NaN
# 1048571         NaN         NaN              NaN                  NaN
# 1048572         NaN         NaN              NaN                  NaN
# 1048573         NaN         NaN              NaN                  NaN
# 1048574         NaN         NaN              NaN                  NaN
#
#          NUANCE_le_plus_voté Nombre de voix du candidat_y  \
# 0                        UMP                        175.0
# 1                        UMP                         66.0
# 2                        SOC                        286.0
# 3                        UMP                        339.0
# 4                        UMP                        291.0
# ...                      ...                          ...
# 1048570                  NaN                          NaN
# 1048571                  NaN                          NaN
# 1048572                  NaN                          NaN
# 1048573                  NaN                          NaN
# 1048574                  NaN                          NaN
#
#         % Voix/Exp_le_plus_voté
# 0                     55.205047
# 1                     54.098361
# 2                     54.894434
# 3                     58.047945
# 4                     52.057245
# ...                         ...
# 1048570                     NaN
# 1048571                     NaN
# 1048572                     NaN
# 1048573                     NaN
# 1048574                     NaN
#
# [1048575 rows x 40 columns]

# %%
df_commune[df_commune['Unnamed: 33'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, commune_code, N° de bureau de vote, longitude_x, latitude, Inscrits, Votants, Exprimés, Nom du candidat, Prénom du candidat, Code nuance du candidat, Nombre de voix du candidat, % Voix/Exp, Nom du candidat.1, Prénom du candidat.1, Code nuance du candidat.1, Nombre de voix du candidat.1, % Voix/Exp.1, Nom du candidat.2, Prénom du candidat.2, Code nuance du candidat.2, Nombre de voix du candidat.2, % Voix/Exp.2, Nom du candidat.3, Prénom du candidat.3, Code nuance du candidat.3, Nombre de voix du candidat.3, % Voix/Exp.3, Unnamed: 27, Unnamed: 28, Unnamed: 29, Unnamed: 30, Unnamed: 31, Unnamed: 32, Unnamed: 33, NOM_le_plus_voté, PRENOM_le_plus_voté, NUANCE_le_plus_voté, Nombre de voix du candidat_y, % Voix/Exp_le_plus_voté]
# Index: []
#
# [0 rows x 40 columns]

# %%
# number = 26, 25, 24, 23, ... , 7

def makeDataFrame(number):
    global df_commune
    
    # 1) Make a new DataFrame 
    index_list = df_commune[df_commune['Nom du candidat.'+str(number)].notnull()].index.tolist()
    globals()['df_voix_'+str(number)] = pd.DataFrame(df_commune, index=index_list)
    
    # 2) df_commune - df_new_dataframe
    df = pd.concat([df_commune, globals()['df_voix_'+str(number)]])
    df = df.drop_duplicates(keep=False)
    df_commune = df
    
    # 3) Make Excel File
    globals()['df_voix_'+str(number)].to_excel('DataFrame pour les législatives (1er tour de 2012)/df_voix_'+str(number)+'.xlsx')

# %%
for number in range(26,5,-1):
    if number == 6:
        df_commune.to_excel('DataFrame pour les législatives (1er tour de 2012)/df_voix_6_to_0.xlsx')
    makeDataFrame(number)
