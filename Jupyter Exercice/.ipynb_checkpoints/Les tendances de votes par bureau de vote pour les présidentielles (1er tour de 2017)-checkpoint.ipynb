# %%
import pandas as pd

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('geo_bureaux_de_vote_md.xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
# df_geo[df.geo['longtitude'].notnull] --> Delete
# df_geo.groupby(df_geo.commune_code.apply(type) != str).apply(lambda x: x.sort_values('commune_code')).to_excel("geo_bureaux_de_vote_md.xlsx")
# --> Sort
# df_geo.to_excel('.xlsx')

df_geo.head(5)
# Out:
#    commune_code  Unnamed: 1     commune_code.1                libelle code  \
# 0           0.0       44769      ch des Ecole"  185 chemin des Ecoles  NaN
# 1           NaN       32924  20 rue de Nébing"       20 rue de Nébing  NaN
# 2           NaN       24894              2A001                    Afa    4
# 3           NaN       49307              2A004                Ajaccio   38
# 4           NaN       36732              2A004                Ajaccio   33
#
#             libelle.1 num_voie code_postal  commune  canton_code  \
# 0                 NaN    74930   46.110407     0.78  housenumber
# 1                 NaN    57670   48.890144     0.69  housenumber
# 2  Bureau de Vote n°4      NaN       20167      AFA          NaN
# 3           BUREAU 38      NaN       20090  AJACCIO          NaN
# 4           BUREAU 33      NaN       20090  AJACCIO          NaN
#
#                              circonscription_code         longitude  \
# 0          185 Chemin des Ecoles 74930 Pers-Jussy  74211_0447_00185
# 1  20 Rue de Nebing 57670 Marimont-lès-Bénestroff  57446_0007_00020
# 2                                           2A-01          8.782253
# 3                                           2A-02          8.738127
# 4                                           2A-02          8.758254
#
#     latitude              geo_score  geo_type           geo_id geo_ligne
# 0          G  185 CHEMIN DES ECOLES       NaN              NaN       NaN
# 1          G       20 RUE DE NEBING       NaN              NaN       NaN
# 2  42.000764                   0.94  locality       2a001_b087         G
# 3  41.923454                   0.33    street  BANO_2A0040270S         D
# 4  41.937837                   0.49    street  BANO_2A0041004P         G
