# %%
import pandas as pd

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('geo_bureaux_de_vote_md.xlsx')

# %%
excel_votes_bureaux_de_vote = pd.ExcelFile('Les tendances de votes par bureau de vote pour les législatives (2eme tour de 2017).xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
df_votes = pd.read_excel(excel_votes_bureaux_de_vote)

# %%
df_geo.rename(columns={'code':'Code du b.vote'}, inplace=True)
df_geo
# Out:
#        Unnamed: 0 commune_code                  libelle Code du b.vote  \
# 0               0         1001  L'Abergement-Clémenciat              1
# 1               1         1002    L'Abergement-de-Varey              1
# 2               2         1004        Ambérieu-en-Bugey              1
# 3               3         1004        Ambérieu-en-Bugey              2
# 4               4         1004        Ambérieu-en-Bugey              3
# ...           ...          ...                      ...            ...
# 60566       60569        2B352          Ville-di-Paraso              1
# 60567       60570        2B353     Ville-di-Pietrabugno              1
# 60568       60571        2B353     Ville-di-Pietrabugno              2
# 60569       60572        2B354                  Vivario              1
# 60570       60573        2B355                Volpajola              2
#
#                        libelle.1 code_postal                commune  \
# ...

# %%
df_votes.rename(columns={'Code du département':'commune_code'}, inplace=True)
df_votes
# Out:
#         commune_code Libellé du département  Code de la circonscription  \
# 0               1001                    Ain                         4.0
# 1               1002                    Ain                         5.0
# 2               1004                    Ain                         5.0
# 3               1004                    Ain                         5.0
# 4               1004                    Ain                         5.0
# ...              ...                    ...                         ...
# 1048570            0                    NaN                         NaN
# 1048571            0                    NaN                         NaN
# 1048572            0                    NaN                         NaN
# 1048573            0                    NaN                         NaN
# 1048574            0                    NaN                         NaN
#
#         Libellé de la circonscription  Code de la commune  \
# ...

# %%
# Inner Join
df_INNER_JOIN = pd.merge(df_geo, df_votes, on=['commune_code','Code du b.vote'])

# %%
df_INNER_JOIN
# Out:
#        Unnamed: 0 commune_code                  libelle Code du b.vote  \
# 0               0         1001  L'Abergement-Clémenciat              1
# 1               1         1002    L'Abergement-de-Varey              1
# 2               2         1004        Ambérieu-en-Bugey              1
# 3               3         1004        Ambérieu-en-Bugey              2
# 4               4         1004        Ambérieu-en-Bugey              3
# ...           ...          ...                      ...            ...
# 54614       58413        95680          Villiers-le-Bel             11
# 54615       58414        95680          Villiers-le-Bel             12
# 54616       58415        95680          Villiers-le-Bel             13
# 54617       58416        95682          Villiers-le-Sec              1
# 54618       58417        95690      Wy-dit-Joli-Village              1
#
#                                                libelle.1 code_postal  \
# ...

# %%
df_INNER_JOIN.to_excel('Les tendances de votes avec cordonnées pour les législatives (2eme tour de 2017).xlsx')
