# %%
import pandas as pd

# %%
excel_geo_bureaux_de_vote = pd.ExcelFile('EXCEL/geo_bureaux_de_vote_md.xlsx')

# %%
excel_votes_bureaux_de_vote = pd.ExcelFile('EXCEL/Original/Les tendances de votes par bureau de vote pour les législatives (1er tour de 2002).xlsx')

# %%
df_geo = pd.read_excel(excel_geo_bureaux_de_vote)

# %%
df_votes = pd.read_excel(excel_votes_bureaux_de_vote)

# %%
df_geo.rename(columns={'code':'N° de bureau de vote'}, inplace=True)
df_geo
# Out:
#        Unnamed: 0 commune_code                  libelle N° de bureau de vote  \
# 0               0         1001  L'Abergement-Clémenciat                    1
# 1               1         1002    L'Abergement-de-Varey                    1
# 2               2         1004        Ambérieu-en-Bugey                    1
# 3               3         1004        Ambérieu-en-Bugey                    2
# 4               4         1004        Ambérieu-en-Bugey                    3
# ...           ...          ...                      ...                  ...
# 60566       60569        2B352          Ville-di-Paraso                    1
# 60567       60570        2B353     Ville-di-Pietrabugno                    1
# 60568       60571        2B353     Ville-di-Pietrabugno                    2
# 60569       60572        2B354                  Vivario                    1
# 60570       60573        2B355                Volpajola                    2
#
# ...

# %%
df_votes.rename(columns={'Code INSEE':'commune_code'}, inplace=True)
df_votes
# Out:
#        commune_code N° de bureau de vote        Nom de la commune  Inscrits  \
# 0              1001                    1  L'Abergement-Clémenciat       568
# 1              1001                    1  L'Abergement-Clémenciat       568
# 2              1001                    1  L'Abergement-Clémenciat       568
# 3              1001                    1  L'Abergement-Clémenciat       568
# 4              1001                    1  L'Abergement-Clémenciat       568
# ...             ...                  ...                      ...       ...
# 888876        95690                    1      Wy-dit-Joli-Village       252
# 888877        95690                    1      Wy-dit-Joli-Village       252
# 888878        95690                    1      Wy-dit-Joli-Village       252
# 888879        95690                    1      Wy-dit-Joli-Village       252
# 888880        95690                    1      Wy-dit-Joli-Village       252
#
# ...

# %%
# Inner Join
df_INNER_JOIN = pd.merge(df_geo, df_votes, on=['commune_code','N° de bureau de vote'])
df_INNER_JOIN.to_excel('EXCEL/Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002).xlsx')

# %%
df_INNER_JOIN
# Out:
#         Unnamed: 0 commune_code                  libelle N° de bureau de vote  \
# 0                0         1001  L'Abergement-Clémenciat                    1
# 1                0         1001  L'Abergement-Clémenciat                    1
# 2                0         1001  L'Abergement-Clémenciat                    1
# 3                0         1001  L'Abergement-Clémenciat                    1
# 4                0         1001  L'Abergement-Clémenciat                    1
# ...            ...          ...                      ...                  ...
# 680441       58417        95690      Wy-dit-Joli-Village                    1
# 680442       58417        95690      Wy-dit-Joli-Village                    1
# 680443       58417        95690      Wy-dit-Joli-Village                    1
# 680444       58417        95690      Wy-dit-Joli-Village                    1
# 680445       58417        95690      Wy-dit-Joli-Village                    1
#
# ...

# %%
df_INNER_JOIN = pd.read_excel('EXCEL/Les tendances de votes avec cordonnées pour les législatives (1er tour de 2002).xlsx')

# %%
df=df_INNER_JOIN.groupby(['commune_code', 'N° de bureau de vote'])['Nombre de voix du candidat'].idxmax()
# df_votes.groupby(['Code Commune (Insee Code)', 'N° de bureau de vote'])['Nombre de voix du candidat'].max()

list_index_le_plus_vote=df.to_frame()['Nombre de voix du candidat'].tolist()

df_le_plus_vote= pd.DataFrame(df_INNER_JOIN,
                  index=list_index_le_plus_vote)

# %%
# If datas is not a type "float", check type with 'apply(type)'
# df_INNER_JOIN[df_INNER_JOIN['Nombre de voix du candidat'].apply(type) == str][['commune_code','N° de bureau de vote']].to_excel('fuckyou.xlsx')

# %%
df_le_plus_vote.to_excel('DataFrame pour les législatives (1er tour de 2002)/[Pandas] 1,2/df_le_plus_vote.xlsx')
